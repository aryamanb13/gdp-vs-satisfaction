# %% [markdown]
# # GDP Per Capita Versus Life Satisfaction
# Project to understand linear regression by predicting relation between GDP Per Capita and Life Satisfaction

# %% [markdown]
# ### Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_model

# %% [markdown]
# ### Loading Data

# %%
oecd_bli = pd.read_csv("Better_Life_Index.csv", thousands = ',')  # OECD Better Life Index 2020
gdp_per_capita = pd.read_csv("WEO_Data.csv", thousands = ',', na_values = 'n/a', encoding = 'latin1')  # WEO GDP Per Capita 2020
oecd_bli.head()
# Out:
#   LOCATION         Country INDICATOR                 Indicator MEASURE  \
# 0      AUS       Australia   JE_LMIS  Labour market insecurity       L
# 1      AUT         Austria   JE_LMIS  Labour market insecurity       L
# 2      BEL         Belgium   JE_LMIS  Labour market insecurity       L
# 3      CAN          Canada   JE_LMIS  Labour market insecurity       L
# 4      CZE  Czech Republic   JE_LMIS  Labour market insecurity       L
#
#   Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0   Value        TOT      Total        PC  Percentage               0
# 1   Value        TOT      Total        PC  Percentage               0
# 2   Value        TOT      Total        PC  Percentage               0
# 3   Value        TOT      Total        PC  Percentage               0
# 4   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value  Flag Codes  Flags
# ...

# %%
gdp_per_capita.head()
# Out:
#        Country                                 Subject Descriptor  \
# 0  Afghanistan  Gross domestic product per capita, current prices
# 1      Albania  Gross domestic product per capita, current prices
# 2      Algeria  Gross domestic product per capita, current prices
# 3      Andorra  Gross domestic product per capita, current prices
# 4       Angola  Gross domestic product per capita, current prices
#
#           Units  Scale                      Country/Series-specific Notes  \
# 0  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 1  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 2  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 3  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
# 4  U.S. dollars  Units  See notes for:  Gross domestic product, curren...
#
#         2020  Estimates Start After
# 0    611.268                 2019.0
# 1   5152.560                 2020.0
# ...

# %% [markdown]
# ### Preparing Data

# %%
oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")  # Setting Country name as Index

# %%
gdp_per_capita.rename(columns={"2020": "GDP per capita"}, inplace=True)  # Renaming Columns
gdp_per_capita.set_index("Country", inplace=True)  # Setting Country name as Index

# %%
full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,
                                  left_index=True, right_index=True)  # Merging tables

# %%
full_country_stats.head()
# Out:
#            Air pollution  Dwellings without basic facilities  \
# Country
# Australia            5.0                                 NaN
# Austria             16.0                                 0.9
# Belgium             15.0                                 1.9
# Brazil              10.0                                 6.7
# Canada               7.0                                 0.2
#
#            Educational attainment  Employees working very long hours  \
# Country
# Australia                    81.0                              13.04
# Austria                      85.0                               6.66
# Belgium                      77.0                               4.75
# Brazil                       49.0                               7.13
# Canada                       91.0                               3.69
#
#            Employment rate  Feeling safe walking alone at night  \
# Country
# Australia             73.0                                 63.5
# ...

# %%
full_country_stats.sort_values(by="GDP per capita", inplace=True)  # Sorting by GDP per Capita

# %%
full_country_stats.head()
# Out:
#               Air pollution  Dwellings without basic facilities  \
# Country
# Colombia               10.0                                23.9
# South Africa           22.0                                37.0
# Brazil                 10.0                                 6.7
# Mexico                 16.0                                25.5
# Turkey                 20.0                                 8.0
#
#               Educational attainment  Employees working very long hours  \
# Country
# Colombia                        54.0                              26.56
# South Africa                    73.0                              18.12
# Brazil                          49.0                               7.13
# Mexico                          38.0                              28.70
# Turkey                          39.0                              32.64
#
#               Employment rate  Feeling safe walking alone at night  \
# Country
# ...

# %%
country_stats = full_country_stats[["GDP per capita", 'Life satisfaction']]  # Choosing GDP per Capita and Life Stisfaction
country_stats.head()
# Out:
#               GDP per capita  Life satisfaction
# Country
# Colombia             5390.92                6.3
# South Africa         5624.50                4.7
# Brazil               6822.56                6.4
# Mexico               8403.60                6.5
# Turkey               8610.03                5.5

# %%
X = np.c_[country_stats["GDP per capita"]]  # Independent Variable
y = np.c_[country_stats["Life satisfaction"]]  # Dependent Variable

# %% [markdown]
# ### Visualising the Data

# %%
country_stats.plot(kind = "scatter", x = "GDP per capita", y = "Life satisfaction")
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='Life satisfaction'>

# %% [markdown]
# ### Selecting a Model

# %%
model = sklearn.linear_model.LinearRegression()  # Linear regression is chosen

# %% [markdown]
# ### Training the Model

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Making Prediction for India

# %%
X_new = [[1929.68]] # India per capita GDP

# %%
model.predict(X_new)
# Out:
# array([[5.79784048]])

# %% [markdown]
# According to the model, Life Satisfaction rating of India is predicted to be 5.8
